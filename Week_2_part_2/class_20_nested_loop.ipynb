# %%
for i in range(5): # 0,1,2,3,4
    for j in range(4):# 0, 1, 2, 3
        print(f'{i} - {j}', end = "  ")
    print()
# Out:
# 0 - 0  0 - 1  0 - 2  0 - 3
# 1 - 0  1 - 1  1 - 2  1 - 3
# 2 - 0  2 - 1  2 - 2  2 - 3
# 3 - 0  3 - 1  3 - 2  3 - 3
# 4 - 0  4 - 1  4 - 2  4 - 3

# %%
for i in range(1, 4): # 1,2,3
    for j in range(1, 4): # 1,2,3
        print(f"{i}-{j}", end = " ")
# Out:
# 1-1 1-2 1-3 2-1 2-2 2-3 3-1 3-2 3-3

# %% [markdown]
# Home-Work - sir gave on vedio

# %%
for i in range(4, 7): # 4,5,6
   
    for j in range(1, 4): # 1, 2, 3
       
         print(f" {i} - {j}", end = "  ")

    print()     




#output: 4-1 4-2 4-3
        #5-1 5-2 5-3
        #6-1 6-2 6-3
# Out:
#  4 - 1   4 - 2   4 - 3
#  5 - 1   5 - 2   5 - 3
#  6 - 1   6 - 2   6 - 3

# %%
for i in range(1, 5):
    print("*" * i)
# Out:
# *
# **
# ***
# ****

# %%
for i in range(1, 10):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
