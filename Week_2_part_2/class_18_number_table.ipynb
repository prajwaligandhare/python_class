# %% [markdown]
# Apni pasand ke number ka table 1–10 print karo.

# %%
num = 9
for i in range(0, 10):
    print(f"{num} x {i} = {num * i}")
# Out:
# 9 x 0 = 0
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
