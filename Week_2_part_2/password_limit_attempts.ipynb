# %%
print("=================PasswordAttempts===================")

password = "Python@2345"

attempts = 0

while attempts < 3:  
  user_password = input("Enter the password")

  if user_password == password:
     print("Access Granted")
     break

  else:
      print("Access Denied")
    
      attempts += 1

      if attempts == 3:
   
         print("Account locked")
# Out:
# =================PasswordAttempts===================
# Access Granted
