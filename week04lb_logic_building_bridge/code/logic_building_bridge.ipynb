# %%
total = 0
for n in [3, 5, 2]:
    total = total + n
print(total)
# Out:
# 10

# %% [markdown]
# step  | total | n |
# step1 |   0   | --
# loop1 |   0   |  3 |
# loop1 |   3   |  3 |
# loop2 |   3   |  5 |
# loop2 |   8   |  5 |
# loop3 |   8   |  2 |
# loop3 |   10  |  2 |
#
# print | 10

# %% [markdown]
# Concept 2 - Ab thoda mushkil (nested + if)

# %%
count = 0 #0
for word in ["hi", "sun", "go"]: #hi
    for letter in word: #h in hi>>, 
        if letter in "aeiou":# h >>False
            count = count + 1
print(count)
# Out:
# 3

# %%
x = 5
x = x + 3
x = x * 2
print(x)
# Out:
# 16

# %%
#EN: Predict the final total. HI: Aakhri total predict karo.
total = 0
for n in [1, 2, 3, 4]:
    total = total + n
print(total)
# Out:
# 10

# %%
x = 20
for i in range(4):
    x = x - 5
print(x)
# Out:
# 0

# %%
a = 17
b = 5
print(a // b, a % b)
# Out:
# 3 2

# %%
count = 0
for letter in "python":
    count = count + 1
print(count)
# Out:
# 6

# %%
result = 1
for n in [2, 2, 3]:
    result = result * n
print(result)
# Out:
# 12

# %%
s = "python"
print(s[0], s[-1], s[1:4])
# Out:
# p n yth

# %%
word = ""
for c in "abc":
    word = word + c + "-"
print(word)
# Out:
# a-b-c-

# %%
x = 10
x = x / 2
x = x / 2
print(x)
# Out:
# 2.5

# %%
total = 0
for i in range(2, 6):
    total = total + i
print(total)
# Out:
# 14

# %%
count = 0
for n in [1, 2, 3, 4, 5, 6]:
    if n % 2 == 0:
        count = count + 1
print(count)
# Out:
# 3
