# %%
nums = [1,3,4,2,1,2]

nums.sort()

print(nums)

print(nums[-1])
# Out:
# [1, 1, 2, 2, 3, 4]
# 4

# %% [markdown]
# Concept 1_ Problem: '3 number mai sabse bada'.

# %% [markdown]
# step1: Restate: I have 3 number then get max number / Mere pass 3 numbers hai usmai bada umber lena hai.
#
# step2: Example: a = 5, b = 7, c = 4, >>>> answer b = 7
#
# step3: Pseudocode (it's your choice to use your language to write steps of problem to exicute before writing python code)

# %% [markdown]
# #Pseudocode
#
# 1>> get 3 numbers a, b, c
#
# 2>> consider 'a' is max number
#
# 3>> is b is greter than max number if yes then max number is b else max number
#
# 4>> is c is greter than max number if yes then max number is c else max number
#
# 5>> show max number to user

# %%
a = 5
b = 7
c = 4

max_number = a

if b > max_number:
    max_number = b

if c > max_number:
    max_number = c

print(max_number)
# Out:
# 7

# %% [markdown]
# steps   a   b   c    max_number
#
# step1   5   7   4      -
#
# step2   5   7   4       5
#
# if      5   7   4       7
#
# print 7

# %%
a = 10
b = 5
c = 7

max_number = a

if b > max_number:  # 5 > 10 >>false
    max_number = b

if c > max_number:  # 7 > 10 >> false
    max_number = c

print("Maximum number is",max_number)
# Out:
# Maximum number is 10

# %% [markdown]
# steps    a   b   c   max_number
# step1    10  5   7       ...
# step2    10  5   7         10
# if
# if
#
# print 10

# %% [markdown]
# ##Speudocoe Practice Questions
#
#
# ##Level 1

# %% [markdown]
# 1. Take a number and print it.
#
# #Pseudocode:
#
# 1>> Take a number from user as input
# 2>> Take any values
# 2>>show it.

# %%
number = int(input("Enter any number: "))
print(number)
# Out:
# 10

# %% [markdown]
# 2. Take two numbers and print their sum
#
# Pseudocode:
#
# 1>> Take first number from user as input.
# 2>> Take secomd number from user as input.
# 3>> do addition of both
# 4>> show answer

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

ans = num1 + num2

print("The answer is: ", ans)
# Out:
# The answer is:  4

# %% [markdown]
# steps   num1   num2    ans
# step1     2      2      -
# step2     2      2      4
#
# print   The answer is:  4

# %% [markdown]
# 3. Take two numbers and print their difference
#
# Pseudocode:
#
# 1>> take 1st number from user.
# 2>> take 2nd number from user.
# 3>> do the substraction using both numbers.
# 4>> show the difference.

# %%
n1 = int(input("Enter 1st number: "))
n2 = int(input("Enter 2nd number: "))

diff = n1 - n2

print("The difference is: ", diff)
# Out:
# The difference is:  33

# %% [markdown]
# steps  n1  n2   diff
# step1  78   45    -
# step2  78   45    33
#
# print  The difference is: 33

# %% [markdown]
# 4. Check whether a number is even or odd.
#
# #Pseudocode:
#
# 1>> Take input from user.
# 2>> used if condition & check number is divisible by 2.
# 3>> if its divisibal by 2 then its even number
# 4>> if not then its odd number
# 5>> show the result.

# %%
number = int(input("Enter The number: "))

if number % 2 == 0:
   print(f" {number} is even number")
else:
    print(f" {number} is a odd number")
# Out:
#  2 is even number

# %% [markdown]
# steps  number  even   odd
# step1    2
# if       2       2
#
# print   2 is even number

# %% [markdown]
# 5. Find the smaller of two numbers.
#
# Pseudocode:
#
# 1>> create any numbers list
# 2>> use min function
# 3>> find smallest number
# 4>> show it

# %%
num_list = [3, 5, 6, 1, 4, 2, 3]

smallest = min(num_list)

print("The Smaller number is: ", smallest)
# Out:
# The Smaller number is:  1

# %% [markdown]
# steps     num_list                 smallest
# step1     [3, 5, 6, 1, 4, 2, 3]       -
# step2     [3, 5, 6, 1, 4, 2, 3]        1
#
# print  The Smaller number is: 1
