# %% [markdown]
# IF / ELIF \ ELSE

# %%
is_raining = True

if is_raining:
    print("Take an umbrelaa")
# Out:
# Take an umbrelaa

# %%
is_khushi_happy = True

is_khushi_happy = input("Is Khushi happy? ")

if is_khushi_happy:
    print("Start learning python")


print("End of the program")
# Out:
# Start learning python
# End of the program

# %% [markdown]
# Concept 2 --else (warna ye karo)

# %%
is_khushi_happy = False

print("If block is executing......")
if is_khushi_happy:
    print("Start learning python")
    print("If block is executed")
else:
    print("Make her happy")

    print("Code is end")
# Out:
# If block is executing......
# Make her happy
# Code is end

# %% [markdown]
# concept 3 - elif (ek aur chnace)

# %%
print("=============== Check Grade Program ====================")

marks = input(f"Enter valid input number from [0 - 100] or entercharacter only 'A': ")

shreya_grade = str(40)

if shreya_grade == "A":
    print("student was absenr")

elif shreya_grade >= str(90):
    print("Grade A")

elif (shreya_grade >= str(70)) and (shreya_grade < str(90)):
    print("Grade B")

elif (shreya_grade >= str(50)) and (shreya_grade < str(70)):
    print("Grade C")

elif (shreya_grade < str(50)):
    print("Grade D")
   
    print("Failed")


print("=================Thank you for using check Grade Pogram================")
# Out:
# =============== Check Grade Program ====================
# Grade D
# Failed
# =================Thank you for using check Grade Pogram================

# %%
bool(-5)
# Out:
# True
