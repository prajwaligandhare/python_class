# %% [markdown]
# CLASS 24 — Tuples & Unpacking

# %%
10,20
# Out:
# (10, 20)

# %%
type((10, 20))
# Out:
# tuple

# %%
user_1 = ("Asha", 56, "Hyd")
print(user_1)
len(user_1)
# Out:
# ('Asha', 56, 'Hyd')
# 3

# %% [markdown]
#  Concept 2 — immutability (badal nahi sakte)

# %%
user_1[1] = "98"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 user_1[1] = "98"
#
# TypeError: 'tuple' object does not support item assignment

# %%
user_1_1 = ("Asha", 98, "Hyd")
user_1_1
# Out:
# ('Asha', 98, 'Hyd')

# %% [markdown]
# Concept 3 — unpacking (ek saath kai variables mein kholna)

# %%
#a = 10
#b = 20

point = (10, 20)

a, b = point

print(a, b)
# Out:
# 10 20

# %%
Asha=Raju=Duja=Khuja="ABC Collage"

# %%
Khuja
# Out:
# 'ABC Collage'

# %%
Duja
# Out:
# 'ABC Collage'

# %% [markdown]
#  Concept 4 — swap trick (do values aapas mein badlo)

# %%
a = 30
b = 40

#temp = a #30
#a = b #40
#b = temp #30

#In tuple how to swap in correct way:
a, b = b, a
print(f"A: {a}, B: {b}")
# Out:
# A: 40, B: 30

# %%
x = 3
y= 6
z = 2

x, y, z = z, x, y

print(x, y, z)
# Out:
# 2 3 6

# %% [markdown]
# CLASS 25 — Advanced Strings (Practice Class)

# %%
ai_ans = [" Hi ! how can i help you ?", 
"I am good, thank you", 
"I am a chatbot",

"""Hi, kaju It's nice to meet you.
what would you like to talk about or week"""]

print(ai_ans)
print(len(ai_ans))
# Out:
# [' Hi ! how can i help you ?', 'I am good, thank you', 'I am a chatbot', "Hi, kaju It's nice to meet you.\nwhat would you like to talk about or week"]
# 4

# %% [markdown]
# Concept 1 — string bhi ek sequence hai!

# %%
word = "Python"

print(word[::-1])
# Out:
# nohtyP

# %%
max(word)
# Out:
# 'y'

# %%
min(word)
# Out:
# 'P'

# %%
ord("P")
# Out:
# 80

# %%
for char in word:
    print(f"{char} : {ord(char)}")
# Out:
# P : 80
# y : 121
# t : 116
# h : 104
# o : 111
# n : 110

# %%
chr(15816)
# Out:
# '㷈'

# %%
chr(128515)
chr(128516)
chr(128517)
chr(128518)
chr(128519)
chr(128520)
# Out:
# '😈'

# %%
chr(128519)
# Out:
# '😇'

# %%
ord("🤣")
# Out:
# 129315

# %%
ord('😇')
# Out:
# 128519

# %% [markdown]
#  Concept 2 — .split() aur .join() (todna aur jodna)

# %%
word.split("t")
# Out:
# ['Py', 'hon']

# %%
"Asha.more".split(".")
# Out:
# ['Asha', 'more']

# %%
"1-2-03-4-5-6-7".split("-")
# Out:
# ['1', '2', '03', '4', '5', '6', '7']

# %%
"-".join(['1', '2', '03', '4', '5', '6', '7'])
# Out:
# '1-2-03-4-5-6-7'

# %%
"/".join(["Asha", "more", "kaju"])
# Out:
# 'Asha/more/kaju'

# %%
word
# Out:
# 'Python'

# %%
list(word)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
word.capitalize()
# Out:
# 'Python'

# %%
lang = "marathi"

lang
# Out:
# 'marathi'

# %%
lang.capitalize()
# Out:
# 'Marathi'

# %%
lang.upper()
# Out:
# 'MARATHI'

# %%
lang.lower()
# Out:
# 'marathi'

# %%
lang.count("a")
# Out:
# 2

# %%
lang.find("t")
# Out:
# 4

# %%
lang_1 = "marathi"
lang_1.strip()
# Out:
# 'marathi'

# %%
lang_1.endswith("i")
# Out:
# True

# %%
sentence = " I  love      python    toooooo much. "

# %%
sentence.lstrip()
# Out:
# 'I  love      python    toooooo much. '

# %%
sentence.rstrip()
# Out:
# ' I  love      python    toooooo much.'

# %%
sentence.split(" ")
# Out:
# ['',
#  'I',
#  '',
#  'love',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'python',
#  '',
#  '',
#  '',
#  'toooooo',
#  'much.',
#  '']

# %%
raw_data = sentence.split(" ")
raw_data.remove("")
raw_data
# Out:
# ['I',
#  '',
#  'love',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'python',
#  '',
#  '',
#  '',
#  'toooooo',
#  'much.',
#  '']

# %%
words_1 = []
for text in raw_data:
    if text:
        words_1.append(text)

clean_data = " ".join(words_1)    
clean_data
# Out:
# 'I love python toooooo much.'

# %% [markdown]
# Join Iterable

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"I Love" + " python"
# Out:
# 'I Love python'
