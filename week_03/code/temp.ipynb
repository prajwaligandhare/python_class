# %%
list_1 = [[23, [23,[45,]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2,3, ["ewdskjfhswkujfh"]], 345.465]][0]]

# %%
list_1 = [[23, [23,[45,]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2,3, ["ewdskjfhswkujfh"]], 345.465]]]

print(list_1[0])
# Out:
# [23, [23, [45]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2, 3, ['ewdskjfhswkujfh']], 345.465]]

# %%
list_1 = [[23, [23,[45,]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2,3, ["ewdskjfhswkujfh"]], 345.465]]]

print(list_1[-1])
# Out:
# [23, [23, [45]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2, 3, ['ewdskjfhswkujfh']], 345.465]]

# %%
list_1 = [[23, [23,[45,]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2,3, ["ewdskjfhswkujfh"]], 345.465]]]
print(list_1[0:1])
# Out:
# [[23, [23, [45]], 45, 'sdfg', [45, 56], [1, 2, 3, [1, 2, 3, ['ewdskjfhswkujfh']], 345.465]]]

# %%
list_1[0][5][3][3][0]
# Out:
# 'ewdskjfhswkujfh'
