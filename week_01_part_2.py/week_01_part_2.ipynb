# %% [markdown]
# #BODMAS

# %%
2 + 2 - 3 = 4 - 3 = 1 >>>>following BODMAS

2 + 2 -3 = 2 - 1 = 1

2 + 2 * 3 = 4 * 3 = 12

2 + 2 * 3 = 2 + 6 = 8

2 * (2 + 3) = 2 * 5 = 10

# %%
#Examples:

23 + 56 * 8 = 23 + 448 = 471

2 - 3 / 10 = 2 - 3.3 = -1.3

100 / 5 + 10 = 100 / 15 = 6.66

(14 + 5) * (5 -3)=  19 * 2 = 38

56 // 34 + 3 * 8 = 25

8 ** 2 = 64

# %% [markdown]
# #Concept 1 - Booleans, Types & Type Conversion

# %%
is_khushi_passed = True
is_ramu_passed = False

print("Is Khushi passed: ", is_khushi_passed)
print("Is Ramu passed: ", is_ramu_passed)
# Out:
# Is Khushi passed:  True
# Is Ramu passed:  False

# %%
weather = "cloudy"
Is_ranin_comming = True
Is_rain_gone = False

print(Is_ranin_comming)
print(Is_rain_gone)
# Out:
# True
# False
