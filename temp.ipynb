# %%
class Car:
    def __init__(self, name, age, color):
        self.name = name
        self.age = age
        self.color = color

# %%
car1 = Car("Chikku", 26, "Black")

print(car1.name)
print(car1.age)
print(car1.color)
# Out:
# Chikku
# 26
# Black

# %%
class StudentInfo:
    def __init__(self, name, age, roll_no):
        self.name = name
        self.age = age
        self.roll_no = roll_no


student1 = StudentInfo("Akash", 30, 1)

print(student1.name)
print(student1.age)
print(student1.roll_no)
# Out:
# Akash
# 30
# 1

# %%
class Dog:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says Woof!") 
      


dog1 = Dog("Buddy", 3) 

dog1.bark()
# Out:
# Buddy says Woof!

# %%
class Vegetables:
      def __init__(self, leaf_vegtbl, raw_vegtbl):
        self.leaf_vegtbl = leaf_vegtbl
        self.raw_vegtbl = raw_vegtbl

      def good_thngs(self):
          print(f"{self.leaf_vegtbl} is a good for health....!")
          print(f"{self.raw_vegtbl} is good for thealth....!")


veggies = Vegetables("Spinach", "Cucumber")  

veggies.good_thngs()

print(veggies.leaf_vegtbl)
# Out:
# Spinach is a good for health....!
# Cucumber is good for thealth....!
# Spinach

# %%
class Counter:
    def __init__(self):
        self.count = 0

    def increase(self):
        self.count = self.count + 1

c = Counter() 

c.increase()
c.increase()

print(c.count)
# Out:
# 2

# %%
class CountDownNumbers:
      def __init__(self):
         self.count_numbers = 0

      def increase_num(self):
          self.count_numbers = self.count_numbers + 1

cdn = CountDownNumbers()

cdn.increase_num()
cdn.increase_num()

print(cdn.count_numbers)
# Out:
# 2

# %%
### Students Details ###

class Students:
      def __init__(self, name, age, roll_no):
        self.name = name
        self.age = age
        self.roll_no = roll_no

      def display(self):
          print("***********Students Details***********")
          print("Name:", self.name)
          print("Age:", self.age)
          print("Roll No:", self.roll_no)

name = input("Enter You're Name: ")
age = int(input("Enter You're Age: "))
roll_no = int(input("Enter you're Roll Number: "))

student1 = Students(name, age, roll_no)

student1.display()
# Out:
# ***********Students Details***********
# Name: Prajwali
# Age: 30
# Roll No: 18

# %% [markdown]
# ## Resume##
#
# class StudentsResume:
#       def __init__(self, name, age, )
